# %% [markdown]
# # 测试集图像分类预测结果
#
# 使用训练好的图像分类模型，预测测试集的所有图像，得到预测结果表格。
#
# 同济子豪兄：https://space.bilibili.com/1900783
#
# [代码运行云GPU环境](https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1)：GPU RTX 3060、CUDA v11.2

# %% [markdown]
# ## 导入工具包

# %%
import os
from tqdm import tqdm

import numpy as np
import pandas as pd

from PIL import Image

import torch
import torch.nn.functional as F

# 有 GPU 就用 GPU，没有就用 CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('device', device)
# Out:
# device cuda:0

# %% [markdown]
# ## 图像预处理

# %%
from torchvision import transforms

# # 训练集图像预处理：缩放裁剪、图像增强、转 Tensor、归一化
# train_transform = transforms.Compose([transforms.RandomResizedCrop(224),
#                                       transforms.RandomHorizontalFlip(),
#                                       transforms.ToTensor(),
#                                       transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#                                      ])

# 测试集图像预处理-RCTN：缩放、裁剪、转 Tensor、归一化
test_transform = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize(
                                         mean=[0.485, 0.456, 0.406], 
                                         std=[0.229, 0.224, 0.225])
                                    ])

# %% [markdown]
# ## 载入测试集（和训练代码教程相同）

# %%
# 数据集文件夹路径
dataset_dir = 'fruit30_split'
test_path = os.path.join(dataset_dir, 'val')
from torchvision import datasets
# 载入测试集
test_dataset = datasets.ImageFolder(test_path, test_transform)
print('测试集图像数量', len(test_dataset))
print('类别个数', len(test_dataset.classes))
print('各类别名称', test_dataset.classes)
# 载入类别名称 和 ID索引号 的映射字典
idx_to_labels = np.load('idx_to_labels.npy', allow_pickle=True).item()
# 获得类别名称
classes = list(idx_to_labels.values())
print(classes)
# Out:
# 测试集图像数量 1078
# 类别个数 30
# 各类别名称 ['哈密瓜', '圣女果', '山竹', '杨梅', '柚子', '柠檬', '桂圆', '梨', '椰子', '榴莲', '火龙果', '猕猴桃', '石榴', '砂糖橘', '胡萝卜', '脐橙', '芒果', '苦瓜', '苹果-红', '苹果-青', '草莓', '荔枝', '菠萝', '葡萄-白', '葡萄-红', '西瓜', '西红柿', '车厘子', '香蕉', '黄瓜']
# ['哈密瓜', '圣女果', '山竹', '杨梅', '柚子', '柠檬', '桂圆', '梨', '椰子', '榴莲', '火龙果', '猕猴桃', '石榴', '砂糖橘', '胡萝卜', '脐橙', '芒果', '苦瓜', '苹果-红', '苹果-青', '草莓', '荔枝', '菠萝', '葡萄-白', '葡萄-红', '西瓜', '西红柿', '车厘子', '香蕉', '黄瓜']

# %% [markdown]
# ## 导入训练好的模型

# %%
model = torch.load('checkpoints/fruit30_pytorch_20220814.pth')
model = model.eval().to(device)

# %% [markdown]
# ## 表格A-测试集图像路径及标注

# %%
test_dataset.imgs[:10]
# Out:
# [('fruit30_split/val/哈密瓜/106.jpg', 0),
#  ('fruit30_split/val/哈密瓜/109.jpg', 0),
#  ('fruit30_split/val/哈密瓜/114.jpg', 0),
#  ('fruit30_split/val/哈密瓜/116.jpg', 0),
#  ('fruit30_split/val/哈密瓜/118.png', 0),
#  ('fruit30_split/val/哈密瓜/123.jpg', 0),
#  ('fruit30_split/val/哈密瓜/127.jpg', 0),
#  ('fruit30_split/val/哈密瓜/129.jpg', 0),
#  ('fruit30_split/val/哈密瓜/131.jpg', 0),
#  ('fruit30_split/val/哈密瓜/133.jpg', 0)]

# %%
img_paths = [each[0] for each in test_dataset.imgs]

# %%
df = pd.DataFrame()
df['图像路径'] = img_paths
df['标注类别ID'] = test_dataset.targets
df['标注类别名称'] = [idx_to_labels[ID] for ID in test_dataset.targets]

# %%
df
# Out:
#                                图像路径  标注类别ID 标注类别名称
# 0     fruit30_split/val/哈密瓜/106.jpg       0    哈密瓜
# 1     fruit30_split/val/哈密瓜/109.jpg       0    哈密瓜
# 2     fruit30_split/val/哈密瓜/114.jpg       0    哈密瓜
# 3     fruit30_split/val/哈密瓜/116.jpg       0    哈密瓜
# 4     fruit30_split/val/哈密瓜/118.png       0    哈密瓜
# ...                             ...     ...    ...
# 1073    fruit30_split/val/黄瓜/87.jpg      29     黄瓜
# 1074     fruit30_split/val/黄瓜/9.jpg      29     黄瓜
# 1075    fruit30_split/val/黄瓜/91.png      29     黄瓜
# 1076    fruit30_split/val/黄瓜/94.jpg      29     黄瓜
# 1077    fruit30_split/val/黄瓜/97.jpg      29     黄瓜
#
# [1078 rows x 3 columns]

# %% [markdown]
# ## 表格B-测试集每张图像的图像分类预测结果，以及各类别置信度

# %%
# 记录 top-n 预测结果
n = 3

# %%
df_pred = pd.DataFrame()
for idx, row in tqdm(df.iterrows()):
    img_path = row['图像路径']
    img_pil = Image.open(img_path).convert('RGB')
    input_img = test_transform(img_pil).unsqueeze(0).to(device) # 预处理
    pred_logits = model(input_img) # 执行前向预测，得到所有类别的 logit 预测分数
    pred_softmax = F.softmax(pred_logits, dim=1) # 对 logit 分数做 softmax 运算

    pred_dict = {}

    top_n = torch.topk(pred_softmax, n) # 取置信度最大的 n 个结果
    pred_ids = top_n[1].cpu().detach().numpy().squeeze() # 解析出类别
    
    # top-n 预测结果
    for i in range(1, n+1):
        pred_dict['top-{}-预测ID'.format(i)] = pred_ids[i-1]
        pred_dict['top-{}-预测名称'.format(i)] = idx_to_labels[pred_ids[i-1]]
    pred_dict['top-n预测正确'] = row['标注类别ID'] in pred_ids
    # 每个类别的预测置信度
    for idx, each in enumerate(classes):
        pred_dict['{}-预测置信度'.format(each)] = pred_softmax[0][idx].cpu().detach().numpy()
        
    df_pred = df_pred.append(pred_dict, ignore_index=True)
# Out:
# 0it [00:00, ?it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1it [00:01,  1.12s/it]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 4it [00:01,  3.98it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 7it [00:01,  7.29it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 10it [00:01, 10.47it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 13it [00:01, 12.59it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 16it [00:01, 14.79it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 19it [00:01, 16.81it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 22it [00:02, 18.19it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 25it [00:02, 19.29it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 28it [00:02, 18.78it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 31it [00:02, 18.79it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 34it [00:02, 19.79it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 37it [00:02, 19.96it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 40it [00:02, 19.95it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 43it [00:03, 20.29it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 46it [00:03, 20.83it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 49it [00:03, 21.19it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 52it [00:03, 21.11it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 55it [00:03, 20.97it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 58it [00:03, 20.93it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 61it [00:03, 21.37it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 64it [00:04, 22.42it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 67it [00:04, 20.89it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 70it [00:04, 20.83it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 73it [00:04, 18.87it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 76it [00:04, 20.21it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 79it [00:04, 19.14it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 81it [00:04, 19.21it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 84it [00:05, 17.74it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 87it [00:05, 19.56it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 90it [00:05, 20.15it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 93it [00:05, 20.51it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 96it [00:05, 20.12it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 99it [00:05, 20.34it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 102it [00:06, 19.09it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 105it [00:06, 20.31it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 108it [00:06, 18.18it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 110it [00:06, 18.29it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 112it [00:06, 17.59it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 115it [00:06, 18.14it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 117it [00:06, 18.53it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 119it [00:06, 18.87it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 122it [00:07, 20.41it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 125it [00:07, 21.48it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 128it [00:07, 21.11it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 131it [00:07, 20.98it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 134it [00:07, 20.33it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 137it [00:07, 19.51it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 140it [00:07, 19.06it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 143it [00:08, 20.37it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 146it [00:08, 20.38it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 149it [00:08, 20.34it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 152it [00:08, 20.06it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 155it [00:08, 20.86it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 158it [00:08, 19.95it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 161it [00:09, 20.59it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 164it [00:09, 20.57it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 167it [00:09, 19.98it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 170it [00:09, 19.63it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 173it [00:09, 20.13it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 176it [00:09, 19.95it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 179it [00:09, 20.51it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 182it [00:10, 21.79it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 185it [00:10, 20.41it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 188it [00:10, 21.59it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 191it [00:10, 22.30it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 194it [00:10, 22.05it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 197it [00:10, 21.37it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 200it [00:10, 20.99it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# ...
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1012it [00:57, 21.27it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1015it [00:57, 21.11it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1018it [00:57, 16.25it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1021it [00:57, 18.04it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1023it [00:57, 17.80it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1026it [00:57, 19.28it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1029it [00:58, 20.93it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1032it [00:58, 20.93it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1035it [00:58, 18.35it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1037it [00:58, 13.31it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1040it [00:58, 15.49it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1043it [00:58, 17.54it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1046it [00:59, 18.69it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1049it [00:59, 18.94it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1052it [00:59, 19.30it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1055it [00:59, 20.66it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1058it [00:59, 21.17it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1061it [00:59, 20.73it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1064it [00:59, 21.94it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1067it [01:00, 22.72it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1070it [01:00, 18.88it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1073it [01:00, 19.22it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1076it [01:00, 17.42it/s]/tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# /tmp/ipykernel_10090/462175456.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pred = df_pred.append(pred_dict, ignore_index=True)
# 1078it [01:00, 17.75it/s]

# %%
df_pred
# Out:
#       top-1-预测ID top-1-预测名称  top-2-预测ID top-2-预测名称  top-3-预测ID top-3-预测名称  \
# 0              4         柚子           5         柠檬           7          梨
# 1              6         桂圆           0        哈密瓜           8         椰子
# 2              0        哈密瓜          26        西红柿          23       葡萄-白
# 3              0        哈密瓜          16         芒果           4         柚子
# 4              4         柚子          11        猕猴桃          23       葡萄-白
# ...          ...        ...         ...        ...         ...        ...
# 1073          29         黄瓜          25         西瓜          17         苦瓜
# 1074          29         黄瓜          17         苦瓜          19       苹果-青
# 1075          29         黄瓜          17         苦瓜          23       葡萄-白
# 1076          29         黄瓜          17         苦瓜          10        火龙果
# 1077          29         黄瓜          17         苦瓜          20         草莓
#
#       top-n预测正确      哈密瓜-预测置信度      圣女果-预测置信度       山竹-预测置信度  ...  \
# 0         False   0.0023508405  4.9450587e-06   4.040416e-07  ...
# 1          True     0.38112196  2.2620793e-07   5.739677e-06  ...
# 2          True     0.53620106      0.0065545    0.006593606  ...
# 3          True      0.7525962   7.142698e-05  2.3597856e-06  ...
# 4         False   0.0050168657  0.00012685276  3.7899506e-05  ...
# ...         ...            ...            ...            ...  ...
# 1073       True    5.93891e-06  1.0501529e-08  9.4484065e-09  ...
# 1074       True  1.1680233e-07  1.3517191e-08  1.0803882e-09  ...
# 1075       True   0.0010911732   0.0001325374  3.1810266e-06  ...
# 1076       True  1.3076195e-06  2.0403022e-05  2.5345668e-07  ...
# 1077       True  1.9314152e-07   3.334234e-07   4.020308e-09  ...
#
#             草莓-预测置信度       荔枝-预测置信度       菠萝-预测置信度     葡萄-白-预测置信度  \
# 0      1.8150844e-07  1.2343869e-06   3.243423e-06  1.1201442e-05
# 1      7.8048956e-08  1.3498897e-06   9.750311e-07   0.0015106951
# 2         0.00933481   0.0071764397   0.0010388161    0.037527516
# 3      3.1976517e-05  0.00025365953  6.0032762e-05   0.0015842838
# 4       0.0007075434  6.7957946e-05  7.4083924e-05    0.115253285
# ...              ...            ...            ...            ...
# 1073   2.6475979e-08  2.7889127e-10  1.8306792e-09  1.6883534e-05
# 1074  1.07798314e-07  3.7485877e-09   9.369248e-09  3.7866417e-07
# 1075   0.00028670047  0.00068920944  0.00012004605   0.0062547335
# 1076   0.00047119765  2.4162005e-06  0.00011817078   0.0013546849
# 1077    9.858399e-05  5.2404936e-08    2.63189e-05   6.695663e-05
#
#          葡萄-红-预测置信度       西瓜-预测置信度      西红柿-预测置信度      车厘子-预测置信度  \
# 0     6.4479555e-06  0.00011587413  0.00012866968  4.1425835e-07
# 1     4.2909367e-05  0.00015741796   6.638699e-07  3.0484532e-06
# 2       0.034991886   0.0015775696     0.26540196  0.00016203609
# 3     3.3540405e-06  0.00027976301  0.00072566525  2.2601515e-07
# 4     0.00076184527  0.00039999862   0.0028934702  2.9521214e-08
# ...             ...            ...            ...            ...
# 1073  4.3673448e-10  0.00083294965   6.809828e-07  3.9479784e-09
# 1074  2.3112412e-08  1.9973343e-06  6.2446254e-08  2.1707587e-08
# 1075   0.0005051993  1.2841905e-05  0.00014438466  7.0835677e-07
# 1076  0.00046067874   0.0014860139   4.860827e-05  4.6543205e-06
# 1077   5.562449e-06  6.0900085e-05   7.503472e-07  1.4810792e-07
#
#            香蕉-预测置信度       黄瓜-预测置信度
# 0     4.6851837e-06   6.217669e-07
# 1      3.217701e-05  2.3868986e-06
# 2       0.005668558    0.001115545
# 3        0.02193577  0.00038454978
# 4     0.00033459536   0.0004361433
# ...             ...            ...
# 1073  2.2288005e-07     0.99909365
# 1074   7.969958e-07      0.9997627
# 1075  0.00039330628      0.9471092
# 1076  0.00011344947      0.9820547
# 1077   9.697259e-07      0.9951879
#
# [1078 rows x 37 columns]

# %% [markdown]
# ## 拼接AB两张表格

# %%
df = pd.concat([df, df_pred], axis=1)

# %%
df
# Out:
#                                图像路径  标注类别ID 标注类别名称  top-1-预测ID top-1-预测名称  \
# 0     fruit30_split/val/哈密瓜/106.jpg       0    哈密瓜           4         柚子
# 1     fruit30_split/val/哈密瓜/109.jpg       0    哈密瓜           6         桂圆
# 2     fruit30_split/val/哈密瓜/114.jpg       0    哈密瓜           0        哈密瓜
# 3     fruit30_split/val/哈密瓜/116.jpg       0    哈密瓜           0        哈密瓜
# 4     fruit30_split/val/哈密瓜/118.png       0    哈密瓜           4         柚子
# ...                             ...     ...    ...         ...        ...
# 1073    fruit30_split/val/黄瓜/87.jpg      29     黄瓜          29         黄瓜
# 1074     fruit30_split/val/黄瓜/9.jpg      29     黄瓜          29         黄瓜
# 1075    fruit30_split/val/黄瓜/91.png      29     黄瓜          29         黄瓜
# 1076    fruit30_split/val/黄瓜/94.jpg      29     黄瓜          29         黄瓜
# 1077    fruit30_split/val/黄瓜/97.jpg      29     黄瓜          29         黄瓜
#
#       top-2-预测ID top-2-预测名称  top-3-预测ID top-3-预测名称  top-n预测正确  ...  \
# 0              5         柠檬           7          梨      False  ...
# 1              0        哈密瓜           8         椰子       True  ...
# 2             26        西红柿          23       葡萄-白       True  ...
# 3             16         芒果           4         柚子       True  ...
# 4             11        猕猴桃          23       葡萄-白      False  ...
# ...          ...        ...         ...        ...        ...  ...
# 1073          25         西瓜          17         苦瓜       True  ...
# 1074          17         苦瓜          19       苹果-青       True  ...
# 1075          17         苦瓜          23       葡萄-白       True  ...
# 1076          17         苦瓜          10        火龙果       True  ...
# 1077          17         苦瓜          20         草莓       True  ...
#
#             草莓-预测置信度       荔枝-预测置信度       菠萝-预测置信度     葡萄-白-预测置信度  \
# 0      1.8150844e-07  1.2343869e-06   3.243423e-06  1.1201442e-05
# 1      7.8048956e-08  1.3498897e-06   9.750311e-07   0.0015106951
# 2         0.00933481   0.0071764397   0.0010388161    0.037527516
# 3      3.1976517e-05  0.00025365953  6.0032762e-05   0.0015842838
# 4       0.0007075434  6.7957946e-05  7.4083924e-05    0.115253285
# ...              ...            ...            ...            ...
# 1073   2.6475979e-08  2.7889127e-10  1.8306792e-09  1.6883534e-05
# 1074  1.07798314e-07  3.7485877e-09   9.369248e-09  3.7866417e-07
# 1075   0.00028670047  0.00068920944  0.00012004605   0.0062547335
# 1076   0.00047119765  2.4162005e-06  0.00011817078   0.0013546849
# 1077    9.858399e-05  5.2404936e-08    2.63189e-05   6.695663e-05
#
#          葡萄-红-预测置信度       西瓜-预测置信度      西红柿-预测置信度      车厘子-预测置信度  \
# 0     6.4479555e-06  0.00011587413  0.00012866968  4.1425835e-07
# 1     4.2909367e-05  0.00015741796   6.638699e-07  3.0484532e-06
# 2       0.034991886   0.0015775696     0.26540196  0.00016203609
# 3     3.3540405e-06  0.00027976301  0.00072566525  2.2601515e-07
# 4     0.00076184527  0.00039999862   0.0028934702  2.9521214e-08
# ...             ...            ...            ...            ...
# 1073  4.3673448e-10  0.00083294965   6.809828e-07  3.9479784e-09
# 1074  2.3112412e-08  1.9973343e-06  6.2446254e-08  2.1707587e-08
# 1075   0.0005051993  1.2841905e-05  0.00014438466  7.0835677e-07
# 1076  0.00046067874   0.0014860139   4.860827e-05  4.6543205e-06
# 1077   5.562449e-06  6.0900085e-05   7.503472e-07  1.4810792e-07
#
#            香蕉-预测置信度       黄瓜-预测置信度
# 0     4.6851837e-06   6.217669e-07
# 1      3.217701e-05  2.3868986e-06
# 2       0.005668558    0.001115545
# 3        0.02193577  0.00038454978
# 4     0.00033459536   0.0004361433
# ...             ...            ...
# 1073  2.2288005e-07     0.99909365
# 1074   7.969958e-07      0.9997627
# 1075  0.00039330628      0.9471092
# 1076  0.00011344947      0.9820547
# 1077   9.697259e-07      0.9951879
#
# [1078 rows x 40 columns]

# %% [markdown]
# ## 导出完整表格

# %%
df.to_csv('测试集预测结果.csv', index=False)
