# %% [markdown]
# # 图像分类数据集探索统计
#
# 同济子豪兄 https://space.bilibili.com/1900783
#
# 代码运行[云GPU平台](https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1)
#
# 2022-7-23

# %% [markdown]
# ## 各类别数据个数柱状图

# %% [markdown]
# ### 导入工具包

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 设置中文字体（选择对应的操作系统）

# %%
# # windows操作系统
# plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签 
# plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %%
# Mac操作系统，参考 https://www.ngui.cc/51cto/show-727683.html
# 下载 simhei.ttf 字体文件
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf

# %%
print(matplotlib.matplotlib_fname())
# Out:
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
# Linux操作系统，例如 云GPU平台：https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1
# 运行完毕后重启 kernel，再从头运行一次
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf -O /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf
# !rm -rf /home/featurize/.cache/matplotlib
# Out:
# --2023-01-17 08:47:21--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10050868 (9.6M) [application/x-font-ttf]
# Saving to: ‘/anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf’
#
# /anaconda/envs/azur 100%[===================>]   9.58M  4.64MB/s    in 2.1s
#
# 2023-01-17 08:47:24 (4.64 MB/s) - ‘/anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf’ saved [10050868/10050868]

# %%
import matplotlib
matplotlib.rc("font",family='SimHei') # 中文字体
# plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %% [markdown]
# ### 导入数据集统计表格

# %%
df = pd.read_csv('数据量统计.csv')

# %%
df.shape
# Out:
# (17, 4)

# %%
df
# Out:
#       class  testset  trainset  total
# 0        丝瓜     37.0     151.0  188.0
# 1       人参果     36.0     146.0  182.0
# 2       佛手瓜     32.0     129.0  161.0
# 3        冬瓜     30.0     123.0  153.0
# 4        南瓜     36.0     147.0  183.0
# 5       哈密瓜     39.0     157.0  196.0
# 6        木瓜     38.0     156.0  194.0
# 7   甜瓜-伊丽莎白     18.0      75.0   93.0
# 8      甜瓜-白     17.0      68.0   85.0
# 9      甜瓜-绿      8.0      35.0   43.0
# 10     甜瓜-金     10.0      42.0   52.0
# 11      白兰瓜     25.0     103.0  128.0
# 12      羊角蜜     39.0     157.0  196.0
# 13       苦瓜     37.0     151.0  188.0
# 14       西瓜     38.0     156.0  194.0
# 15      西葫芦     33.0     136.0  169.0
# 16       黄瓜     36.0     144.0  180.0

# %% [markdown]
# ### 图像数量柱状图可视化

# %%
# 指定可视化的特征
feature = 'total'
# feature = 'trainset'
# feature = 'testset'

# %%
df = df.sort_values(by=feature, ascending=False)

# %%
df.head()
# Out:
#    class  testset  trainset  total
# 5    哈密瓜     39.0     157.0  196.0
# 12   羊角蜜     39.0     157.0  196.0
# 14    西瓜     38.0     156.0  194.0
# 6     木瓜     38.0     156.0  194.0
# 0     丝瓜     37.0     151.0  188.0

# %%
plt.figure(figsize=(22, 7))

x = df['class']
y = df[feature]

plt.bar(x, y, facecolor='#1f77b4', edgecolor='k')

plt.xticks(rotation=90)
plt.tick_params(labelsize=15)
plt.xlabel('类别', fontsize=20)
plt.ylabel('图像数量', fontsize=20)

# plt.savefig('各类别图片数量.pdf', dpi=120, bbox_inches='tight')

plt.show()
# Out:
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21704 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23494 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29916 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32650 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35282 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 34588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19997 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33510 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26524 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 40644 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33446 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20315 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25163 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20908 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20234 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20029 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33678 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32511 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31867 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21035 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21704 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 29916 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32650 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35282 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 34588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 19997 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33510 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 26524 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40644 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33899 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33446 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20315 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25163 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20908 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 29980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20234 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20029 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33678 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32511 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31867 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21035 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(22, 7))
x = df['class']
y1 = df['testset']
y2 = df['trainset']

width = 0.55 # 柱状图宽度

plt.xticks(rotation=90) # 横轴文字旋转

plt.bar(x, y1, width, label='测试集')
plt.bar(x, y2, width, label='训练集', bottom=y1)


plt.xlabel('类别', fontsize=20)
plt.ylabel('图像数量', fontsize=20)
plt.tick_params(labelsize=13) # 设置坐标文字大小

plt.legend(fontsize=16) # 图例

# 保存为高清的 pdf 文件
plt.savefig('各类别图像数量.pdf', dpi=120, bbox_inches='tight')

plt.show()
# Out:
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 21704 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 23494 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 29916 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 32650 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 35282 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 34588 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 19997 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 33510 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 26524 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 40644 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 33899 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 33446 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 20315 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 25163 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 20908 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 30333 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 29980 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 20234 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 20029 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 33678 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 32511 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 31867 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 21035 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 38598 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 35757 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 32451 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21704 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23494 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29916 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32650 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35282 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 34588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19997 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33510 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26524 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 40644 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33446 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20315 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25163 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20908 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20234 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20029 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33678 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32511 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21704 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 29916 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32650 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35282 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 34588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 19997 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33510 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 26524 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40644 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33899 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33446 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20315 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25163 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20908 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 29980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20234 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20029 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33678 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32511 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31867 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21035 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31867 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21035 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38598 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35757 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38598 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35757 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32451 missing from current font.
#   font.set_text(s, 0, flags=flags)
